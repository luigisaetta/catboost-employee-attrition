# %% [markdown]
# ### EDA2
#
# exploring new combination of features

# %%
import pandas as pd
import numpy as np

import ocifs

import matplotlib.pyplot as plt

import seaborn as sns

# %%
# globals
# some columns are not needed. This is the list of columns that will be used
MY_COLUMNS = ['Age', 'Attrition', 'EnvironmentSatisfaction', 'MaritalStatus', 'TravelForWork', 'SalaryLevel', 'JobFunction', 
              'CommuteLength', 'EducationalLevel', 'EducationField', 'MonthlyIncome', 
              'OverTime', 'StockOptionLevel', 'TrainingTimesLastYear', 'YearsSinceLastPromotion', 'WorkLifeBalance']

# %%
# read the csv from Object storage and return a pandas df
def read_from_object_storage(prefix, file_name):
    # get access to OSS as an fs
    # config={} assume resource_principal auth
    fs = ocifs.OCIFileSystem(config={})
    
    FILE_PATH = prefix + file_name
    
    # reading data from Object Storage
    with fs.open(FILE_PATH, 'rb') as f:
        df = pd.read_csv(f)
    
    return df

def compute_distinct(data, columns):
    l_count = []
    for col in columns:
        l_count.append(data[col].nunique())
    
    count_dict = {}
    count_dict['col'] = columns
    count_dict['count'] = l_count

    count_df = pd.DataFrame(count_dict)
    
    return count_df

# %% [markdown]
# ### Reading the dataset from the Object Storage (using OCIFS)

# %%
PREFIX = "oci://data_input@fr95jjtqbdhh/"
FILE_NAME = "orcl_attrition.csv"

# see in functions above
data_orig = read_from_object_storage(prefix=PREFIX, file_name=FILE_NAME)

data_orig.head()
# Out:
#    Age Attrition TravelForWork  SalaryLevel         JobFunction  \
# 0   42       Yes    infrequent         5054  Product Management
# 1   50        No         often         1278  Software Developer
# 2   38       Yes    infrequent         6296  Software Developer
# 3   34        No         often         6384  Software Developer
# 4   28        No    infrequent         2710  Software Developer
#
#    CommuteLength EducationalLevel EducationField  Directs  EmployeeNumber  \
# 0              2               L2  Life Sciences        1               1
# 1              9               L1  Life Sciences        1               2
# 2              3               L2          Other        1               4
# 3              4               L4  Life Sciences        1               5
# 4              3               L1        Medical        1               7
#
#    ...  WeeklyWorkedHours StockOptionLevel  YearsinIndustry  \
# 0  ...                 80                0                8
# 1  ...                 80                1               10
# 2  ...                 80                0                7
# 3  ...                 80                0                8
# 4  ...                 80                1                6
#
#    TrainingTimesLastYear  WorkLifeBalance YearsOnJob  YearsAtCurrentLevel  \
# 0                      0                1          6                    4
# 1                      3                3         10                    7
# 2                      3                3          0                    0
# 3                      3                3          8                    7
# 4                      3                3          2                    2
#
#   YearsSinceLastPromotion  YearsWithCurrManager               name
# 0                       0                     5        Tracy Moore
# 1                       1                     7      Andrew Hoover
# 2                       0                     0         Julie Bell
# 3                       3                     0       Thomas Adams
# 4                       2                     2  Johnathan Burnett
#
# [5 rows x 36 columns]

# %%
data_orig.columns
# Out:
# Index(['Age', 'Attrition', 'TravelForWork', 'SalaryLevel', 'JobFunction',
#        'CommuteLength', 'EducationalLevel', 'EducationField', 'Directs',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'WeeklyWorkedHours', 'StockOptionLevel',
#        'YearsinIndustry', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsOnJob', 'YearsAtCurrentLevel', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'name'],
#       dtype='object')

# %%
data_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   TravelForWork             1470 non-null   object
#  3   SalaryLevel               1470 non-null   int64
#  4   JobFunction               1470 non-null   object
#  5   CommuteLength             1470 non-null   int64
#  6   EducationalLevel          1470 non-null   object
#  7   EducationField            1470 non-null   object
#  8   Directs                   1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  WeeklyWorkedHours         1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  YearsinIndustry           1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsOnJob                1470 non-null   int64
#  32  YearsAtCurrentLevel       1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
#  35  name                      1470 non-null   object
# dtypes: int64(25), object(11)
# memory usage: 413.6+ KB

# %%
for col in data_orig.columns:
    print(col, 'Unique values:', data_orig[col].nunique())
# Out:
# Age Unique values: 43
# Attrition Unique values: 2
# TravelForWork Unique values: 3
# SalaryLevel Unique values: 886
# JobFunction Unique values: 3
# CommuteLength Unique values: 29
# EducationalLevel Unique values: 5
# EducationField Unique values: 6
# Directs Unique values: 1
# EmployeeNumber Unique values: 1470
# EnvironmentSatisfaction Unique values: 4
# Gender Unique values: 2
# HourlyRate Unique values: 71
# JobInvolvement Unique values: 4
# JobLevel Unique values: 5
# JobRole Unique values: 9
# JobSatisfaction Unique values: 4
# MaritalStatus Unique values: 3
# MonthlyIncome Unique values: 1349
# MonthlyRate Unique values: 1427
# NumCompaniesWorked Unique values: 10
# Over18 Unique values: 1
# OverTime Unique values: 2
# PercentSalaryHike Unique values: 15
# PerformanceRating Unique values: 2
# RelationshipSatisfaction Unique values: 4
# WeeklyWorkedHours Unique values: 1
# StockOptionLevel Unique values: 4
# YearsinIndustry Unique values: 40
# TrainingTimesLastYear Unique values: 7
# WorkLifeBalance Unique values: 4
# YearsOnJob Unique values: 37
# YearsAtCurrentLevel Unique values: 19
# YearsSinceLastPromotion Unique values: 16
# YearsWithCurrManager Unique values: 18
# name Unique values: 1453

# %%
# eliminiamo 
to_remove = ['Directs', 'EmployeeNumber', 'name', 'Over18', 'WeeklyWorkedHours']

columns1 = sorted(list(set(data_orig.columns) - set(to_remove)))

print('Rimangono:', len(columns1))
# Out:
# Rimangono: 31

# %%
data1 = data_orig[columns1]

# %%
# cross correlation matrix
tab1 = data1.corr()

tab1
# Out:
#                                Age  CommuteLength  EnvironmentSatisfaction  \
# Age                       1.000000      -0.001686                 0.010146
# CommuteLength            -0.001686       1.000000                -0.016075
# EnvironmentSatisfaction   0.010146      -0.016075                 1.000000
# HourlyRate                0.024287       0.031131                -0.049857
# JobInvolvement            0.029820       0.008783                -0.008278
# JobLevel                  0.509604       0.005303                 0.001212
# JobSatisfaction          -0.004892      -0.003669                -0.006784
# MonthlyIncome             0.497855      -0.017014                -0.006259
# MonthlyRate               0.028051       0.027473                 0.037600
# NumCompaniesWorked        0.299635      -0.029251                 0.012594
# PercentSalaryHike         0.003634       0.040235                -0.031701
# PerformanceRating         0.001904       0.027110                -0.029548
# RelationshipSatisfaction  0.053535       0.006557                 0.007665
# SalaryLevel               0.010661      -0.004994                 0.018355
# StockOptionLevel          0.037510       0.044872                 0.003432
# TrainingTimesLastYear    -0.019621      -0.036942                -0.019359
# WorkLifeBalance          -0.021490      -0.026556                 0.027627
# YearsAtCurrentLevel       0.212901       0.018845                 0.018007
# YearsOnJob                0.311309       0.009508                 0.001458
# YearsSinceLastPromotion   0.216513       0.010029                 0.016194
# YearsWithCurrManager      0.202089       0.014406                -0.004999
# YearsinIndustry           0.680381       0.004628                -0.002693
#
#                           HourlyRate  JobInvolvement  JobLevel  \
# Age                         0.024287        0.029820  0.509604
# CommuteLength               0.031131        0.008783  0.005303
# EnvironmentSatisfaction    -0.049857       -0.008278  0.001212
# HourlyRate                  1.000000        0.042861 -0.027853
# JobInvolvement              0.042861        1.000000 -0.012630
# JobLevel                   -0.027853       -0.012630  1.000000
# JobSatisfaction            -0.071335       -0.021476 -0.001944
# MonthlyIncome              -0.015794       -0.015271  0.950300
# MonthlyRate                -0.015297       -0.016322  0.039563
# NumCompaniesWorked          0.022157        0.015012  0.142501
# PercentSalaryHike          -0.009062       -0.017205 -0.034730
# PerformanceRating          -0.002172       -0.029071 -0.021222
# RelationshipSatisfaction    0.001330        0.034297  0.021642
# SalaryLevel                 0.023373        0.046128  0.002969
# StockOptionLevel            0.050263        0.021523  0.013984
# TrainingTimesLastYear      -0.008548       -0.015338 -0.018191
# WorkLifeBalance            -0.004607       -0.014617  0.037818
# YearsAtCurrentLevel        -0.024106        0.008717  0.389447
# YearsOnJob                 -0.019582       -0.021355  0.534739
# YearsSinceLastPromotion    -0.026716       -0.024184  0.353885
# YearsWithCurrManager       -0.020123        0.025976  0.375281
# YearsinIndustry            -0.002334       -0.005533  0.782208
#
#                           JobSatisfaction  MonthlyIncome  MonthlyRate  \
# Age                             -0.004892       0.497855     0.028051
# CommuteLength                   -0.003669      -0.017014     0.027473
# EnvironmentSatisfaction         -0.006784      -0.006259     0.037600
# HourlyRate                      -0.071335      -0.015794    -0.015297
# JobInvolvement                  -0.021476      -0.015271    -0.016322
# JobLevel                        -0.001944       0.950300     0.039563
# JobSatisfaction                  1.000000      -0.007157     0.000644
# MonthlyIncome                   -0.007157       1.000000     0.034814
# MonthlyRate                      0.000644       0.034814     1.000000
# NumCompaniesWorked              -0.055699       0.149515     0.017521
# PercentSalaryHike                0.020002      -0.027269    -0.006429
# PerformanceRating                0.002297      -0.017120    -0.009811
# RelationshipSatisfaction        -0.012454       0.025873    -0.004085
# SalaryLevel                      0.030568       0.007709    -0.032184
# StockOptionLevel                 0.010690       0.005408    -0.034323
# TrainingTimesLastYear           -0.005779      -0.021736     0.001467
# WorkLifeBalance                 -0.019459       0.030683     0.007963
# YearsAtCurrentLevel             -0.002305       0.363818    -0.012815
# YearsOnJob                      -0.003803       0.514285    -0.023655
# YearsSinceLastPromotion         -0.018214       0.344978     0.001567
# YearsWithCurrManager            -0.027656       0.344079    -0.036746
# YearsinIndustry                 -0.020185       0.772893     0.026442
#
#                           NumCompaniesWorked  ...  RelationshipSatisfaction  \
# Age                                 0.299635  ...                  0.053535
# CommuteLength                      -0.029251  ...                  0.006557
# EnvironmentSatisfaction             0.012594  ...                  0.007665
# HourlyRate                          0.022157  ...                  0.001330
# JobInvolvement                      0.015012  ...                  0.034297
# JobLevel                            0.142501  ...                  0.021642
# JobSatisfaction                    -0.055699  ...                 -0.012454
# MonthlyIncome                       0.149515  ...                  0.025873
# MonthlyRate                         0.017521  ...                 -0.004085
# NumCompaniesWorked                  1.000000  ...                  0.052733
# PercentSalaryHike                  -0.010238  ...                 -0.040490
# PerformanceRating                  -0.014095  ...                 -0.031351
# RelationshipSatisfaction            0.052733  ...                  1.000000
# SalaryLevel                         0.038141  ...                  0.007845
# StockOptionLevel                    0.030075  ...                 -0.045952
# TrainingTimesLastYear              -0.066054  ...                  0.002497
# WorkLifeBalance                    -0.008366  ...                  0.019604
# YearsAtCurrentLevel                -0.090754  ...                 -0.015123
# YearsOnJob                         -0.118421  ...                  0.019367
# YearsSinceLastPromotion            -0.036814  ...                  0.033493
# YearsWithCurrManager               -0.110319  ...                 -0.000867
# YearsinIndustry                     0.237639  ...                  0.024054
#
#                           SalaryLevel  StockOptionLevel  \
# Age                          0.010661          0.037510
# CommuteLength               -0.004994          0.044872
# EnvironmentSatisfaction      0.018355          0.003432
# HourlyRate                   0.023373          0.050263
# JobInvolvement               0.046128          0.021523
# JobLevel                     0.002969          0.013984
# JobSatisfaction              0.030568          0.010690
# MonthlyIncome                0.007709          0.005408
# MonthlyRate                 -0.032184         -0.034323
# NumCompaniesWorked           0.038141          0.030075
# PercentSalaryHike            0.022701          0.007528
# PerformanceRating            0.000470          0.003506
# RelationshipSatisfaction     0.007845         -0.045952
# SalaryLevel                  1.000000          0.042145
# StockOptionLevel             0.042145          1.000000
# TrainingTimesLastYear        0.002441          0.011274
# WorkLifeBalance             -0.037843          0.004129
# YearsAtCurrentLevel          0.009952          0.050818
# YearsOnJob                  -0.034036          0.015058
# YearsSinceLastPromotion     -0.033224          0.014352
# YearsWithCurrManager        -0.026348          0.024698
# YearsinIndustry              0.014519          0.010136
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                   -0.019621        -0.021490
# CommuteLength                         -0.036942        -0.026556
# EnvironmentSatisfaction               -0.019359         0.027627
# HourlyRate                            -0.008548        -0.004607
# JobInvolvement                        -0.015338        -0.014617
# JobLevel                              -0.018191         0.037818
# JobSatisfaction                       -0.005779        -0.019459
# MonthlyIncome                         -0.021736         0.030683
# MonthlyRate                            0.001467         0.007963
# NumCompaniesWorked                    -0.066054        -0.008366
# PercentSalaryHike                     -0.005221        -0.003280
# PerformanceRating                     -0.015579         0.002572
# RelationshipSatisfaction               0.002497         0.019604
# SalaryLevel                            0.002441        -0.037843
# StockOptionLevel                       0.011274         0.004129
# TrainingTimesLastYear                  1.000000         0.028072
# WorkLifeBalance                        0.028072         1.000000
# YearsAtCurrentLevel                   -0.005738         0.049856
# YearsOnJob                             0.003569         0.012089
# YearsSinceLastPromotion               -0.002067         0.008941
# YearsWithCurrManager                  -0.004096         0.002759
# YearsinIndustry                       -0.035662         0.001008
#
#                           YearsAtCurrentLevel  YearsOnJob  \
# Age                                  0.212901    0.311309
# CommuteLength                        0.018845    0.009508
# EnvironmentSatisfaction              0.018007    0.001458
# HourlyRate                          -0.024106   -0.019582
# JobInvolvement                       0.008717   -0.021355
# JobLevel                             0.389447    0.534739
# JobSatisfaction                     -0.002305   -0.003803
# MonthlyIncome                        0.363818    0.514285
# MonthlyRate                         -0.012815   -0.023655
# NumCompaniesWorked                  -0.090754   -0.118421
# PercentSalaryHike                   -0.001520   -0.035991
# PerformanceRating                    0.034986    0.003435
# RelationshipSatisfaction            -0.015123    0.019367
# SalaryLevel                          0.009952   -0.034036
# StockOptionLevel                     0.050818    0.015058
# TrainingTimesLastYear               -0.005738    0.003569
# WorkLifeBalance                      0.049856    0.012089
# YearsAtCurrentLevel                  1.000000    0.758754
# YearsOnJob                           0.758754    1.000000
# YearsSinceLastPromotion              0.548056    0.618409
# YearsWithCurrManager                 0.714365    0.769212
# YearsinIndustry                      0.460365    0.628133
#
#                           YearsSinceLastPromotion  YearsWithCurrManager  \
# Age                                      0.216513              0.202089
# CommuteLength                            0.010029              0.014406
# EnvironmentSatisfaction                  0.016194             -0.004999
# HourlyRate                              -0.026716             -0.020123
# JobInvolvement                          -0.024184              0.025976
# JobLevel                                 0.353885              0.375281
# JobSatisfaction                         -0.018214             -0.027656
# MonthlyIncome                            0.344978              0.344079
# MonthlyRate                              0.001567             -0.036746
# NumCompaniesWorked                      -0.036814             -0.110319
# PercentSalaryHike                       -0.022154             -0.011985
# PerformanceRating                        0.017896              0.022827
# RelationshipSatisfaction                 0.033493             -0.000867
# SalaryLevel                             -0.033224             -0.026348
# StockOptionLevel                         0.014352              0.024698
# TrainingTimesLastYear                   -0.002067             -0.004096
# WorkLifeBalance                          0.008941              0.002759
# YearsAtCurrentLevel                      0.548056              0.714365
# YearsOnJob                               0.618409              0.769212
# YearsSinceLastPromotion                  1.000000              0.510224
# YearsWithCurrManager                     0.510224              1.000000
# YearsinIndustry                          0.404858              0.459188
#
#                           YearsinIndustry
# Age                              0.680381
# CommuteLength                    0.004628
# EnvironmentSatisfaction         -0.002693
# HourlyRate                      -0.002334
# JobInvolvement                  -0.005533
# JobLevel                         0.782208
# JobSatisfaction                 -0.020185
# MonthlyIncome                    0.772893
# MonthlyRate                      0.026442
# NumCompaniesWorked               0.237639
# PercentSalaryHike               -0.020608
# PerformanceRating                0.006744
# RelationshipSatisfaction         0.024054
# SalaryLevel                      0.014519
# StockOptionLevel                 0.010136
# TrainingTimesLastYear           -0.035662
# WorkLifeBalance                  0.001008
# YearsAtCurrentLevel              0.460365
# YearsOnJob                       0.628133
# YearsSinceLastPromotion          0.404858
# YearsWithCurrManager             0.459188
# YearsinIndustry                  1.000000
#
# [22 rows x 22 columns]

# %%
# provo a fare ricerca in automatico
THR = 0.7

for col in tab1.columns:
    print('********')
    print('Esamino:', col)
    cond = (tab1[col] > THR)
    
    print(tab1.loc[cond, col])
    print()
# Out:
# ********
# Esamino: Age
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2c87d4f46b0a> in <module>
#       3     print('********')
#       4     print('Esamino:', col)
# ----> 5     cond = (tab1[col] > THR)
#       6
#       7     print(tab1.loc[cond, col])
#
# NameError: name 'THR' is not defined

# %%
to_remove = to_remove + ['JobLevel', 'YearsinIndustry','YearsOnJob','YearsWithCurrManager', 'PercentSalaryHike']

to_remove

columns2 = sorted(list(set(data_orig.columns) - set(to_remove)))

print('Rimangono:', len(columns2))

# %%
data2 = data_orig[columns2]

tab2 = data2.corr()

for col in tab2.columns:
    print('********')
    print('Esamino:', col)
    cond = (tab2[col] > THR)
    
    print(tab2.loc[cond, col])
    print()

# %%
data = data_orig[columns2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6a3fd81088b6> in <module>
# ----> 1 data = data_orig[columns2]
#
# NameError: name 'columns2' is not defined

# %%
print("Numero di record nel dataset intero:", data.shape[0])

# %%
# distribution of target
FIGSIZE = (9, 6)
plt.figure(figsize=FIGSIZE)
plt.title('Distribution of target values')
plt.grid(True)
sns.histplot(data['Attrition'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-675cd7058ef6> in <module>
#       4 plt.title('Distribution of target values')
#       5 plt.grid(True)
# ----> 6 sns.histplot(data['Attrition'])
#       7 plt.show()
#
# NameError: name 'data' is not defined

# %% [markdown]
# #### il dataset è sbilanciato, la classe positiva è minoritaria

# %%
# compute the ratio, for class weights
condition = data['Attrition'] == 'Yes'

n_pos = data.loc[condition].shape[0]
n_neg = data.shape[0] - n_pos
ratio = n_neg/n_pos

print('Il rapporto negativi/positivi è:', round(ratio, 2))

# %%
# contiamo il numero di valori distinti
# per decidere quali trattare come categoriche e quali come numeriche
count_df = compute_distinct(data, columns2)

count_df

# %%
sns.barplot(y=columns2, x=count_df['count'])
plt.show()

# %%
FIGSIZE = (14, 20)
plt.figure(figsize=FIGSIZE)

# iterasu tutte le colonne
for i, col in enumerate(columns2):
    plt.subplot(7, 4, i+1)
    plt.grid(True)
    cp = sns.countplot(x=data[col])
    cp.set_xlabel(col,fontsize=8)
    cp.set_ylabel('count',fontsize=8)
    cp.tick_params(labelsize=6)
plt.show()

# %% [markdown]
# #### Dalle analisi sopra si giustifica di considerare **MonthlyIncome**, **MonthlyRate**  e **SalaryLevel** come continue numeriche e tutte le altre come categoriche

# %%
columns2
